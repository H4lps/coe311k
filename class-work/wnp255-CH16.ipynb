# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the parameters

k = 1.0        # Constant in the equation (e.g., spring constant)
h_vals = [.01, .02, .03, .05, .1, .2, .3, .5]       # Step size
x_start = 0    # Start of the interval
x_end = 10     # End of the interval
y_0 = 1.0      # Initial condition for y
v_0 = 0.0      # Initial condition for dy/dx


 

# Euler's Method loop
for h in h_vals:
    x_values = np.arange(x_start, x_end + h, h)
    y_values = np.zeros(len(x_values))
    v_values = np.zeros(len(x_values))
    
    # Set initial conditions

    y_values[0] = y_0
    v_values[0] = v_0

    for i in range(1, len(x_values)):
        # Current values
        x_n = x_values[i - 1]
        y_n = y_values[i - 1]
        v_n = v_values[i - 1]    

        # Update equations
        y_values[i] = y_n + h * v_n
        v_values[i] = v_n + h * (-k * y_n)



    # Plot the results

    plt.figure(figsize=(10, 5))
    plt.plot(x_values, y_values, label='Position y(x)')
    plt.plot(x_values, v_values, label='Velocity v(x)', linestyle='--')
    plt.xlabel('x')
    plt.ylabel('y and v')
    plt.title(f"Solution of d²y/dx² = -ky using Euler\'s Method,with h = {h}")
    plt.legend()
    plt.grid(True)

    plt.show()

# %%
# Define the parameters

k_vals = [0.01, 0.1, .5 ,1.0, 1.5, 5.0, 10.0, 50.0]       # Constant in the equation (e.g., spring constant)
h = .01       # Step size
x_start = 0    # Start of the interval
x_end = 10     # End of the interval
y_0 = 1.0      # Initial condition for y
v_0 = 0.0      # Initial condition for dy/dx


 

# Euler's Method loop
for k in k_vals:
    x_values = np.arange(x_start, x_end + h, h)
    y_values = np.zeros(len(x_values))
    v_values = np.zeros(len(x_values))
    
    # Set initial conditions

    y_values[0] = y_0
    v_values[0] = v_0

    for i in range(1, len(x_values)):
        # Current values
        x_n = x_values[i - 1]
        y_n = y_values[i - 1]
        v_n = v_values[i - 1]    

        # Update equations
        y_values[i] = y_n + h * v_n
        v_values[i] = v_n + h * (-k * y_n)



    # Plot the results

    plt.figure(figsize=(10, 5))
    plt.plot(x_values, y_values, label='Position y(x)')
    plt.plot(x_values, v_values, label='Velocity v(x)', linestyle='--')
    plt.xlabel('x')
    plt.ylabel('y and v')
    plt.title(f"Solution of d²y/dx² = -ky using Euler\'s Method,with k = {k}")
    plt.legend()
    plt.grid(True)

    plt.show()

# %% [markdown]
# # Explanation
#
# ### When does it become unstable?
# It seems that when h=0.1 we see a signifciantly larger trough at x ~ 9.5 and therefore the instability is apparent.
#
# ### What happens as you increase k?
# As you increase K the solution becomes significantly more osciallatory, where the wave like shape has a higher frequency.
#
# ### Can the method solve with large h?
# As you increase h your solution will become more noisy. So if you define a large step size as .05 then that still has a good approximation. However, solutions with step sizes greater than .1 do a poor job at approximating the solution.
