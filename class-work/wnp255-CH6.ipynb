# %%
import numpy as np
import time

# %%
def jacobi(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
        # Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
    return x, max_iterations

# %%
def gauss_seidel(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = x.copy()
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
            x_new[i] = (b[i] - s1 - s2) / A[i][i]
        # Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
    return x, max_iterations

# %%
# Matrix A
A = np.array([
    [10, -1,  2,  0,  0],
    [-1, 11, -1,  3,  0],
    [ 2, -1, 10, -1,  0],
    [ 0,  3, -1,  8, -2],
    [ 0,  0,  0, -2,  9]
], dtype=float)

# Vector b
b = np.array([
    14,
    30,
    26,
    25,
    37
], dtype=float)

x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100
start_time = time.perf_counter()
solution, iterations = gauss_seidel(A, b, x0, tol, max_iterations)
end_time = time.perf_counter()
elapsed_time = end_time - start_time
print("Gaus Seidel:")
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
print(f"Method time: {elapsed_time} seconds")

start_time = time.perf_counter()
solution, iterations = jacobi(A, b, x0, tol, max_iterations)
end_time = time.perf_counter()
elapsed_time = end_time - start_time

print("\nJacobi:")
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
print(f"Method time: {elapsed_time} seconds")
# Out:
# Gaus Seidel:
# Solution: [1.4        2.85454545 2.60545455 2.38022727 4.64005051]
# Iterations: 100
# Method time: 0.013967547565698624 seconds
#
# Jacobi:
# Solution: [1.4        2.72727273 2.6        3.125      4.11111111]
# Iterations: 100
# Method time: 0.008673341944813728 seconds

# %%
# Matrix A
A = np.array([
    [1, 2, 3, 0, 0],
    [2, 1, 2, 3, 0],
    [3, 2, 1, 2, 3],
    [0, 3, 2, 1, 2],
    [0, 0, 3, 2, 1]
], dtype=float)

# Vector b
b = np.array([
    14,
    22,
    33,
    26,
    22
], dtype=float)
x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100
start_time = time.perf_counter()
solution, iterations = gauss_seidel(A, b, x0, tol, max_iterations)
end_time = time.perf_counter()
elapsed_time = end_time - start_time
print("Gaus Seidel:")
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
print(f"Method time: {elapsed_time} seconds")

start_time = time.perf_counter()
solution, iterations = jacobi(A, b, x0, tol, max_iterations)
end_time = time.perf_counter()
elapsed_time = end_time - start_time

print("\nJacobi:")
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
print(f"Method time: {elapsed_time} seconds")
# Out:
# Gaus Seidel:
# Solution: [ 14.  -6.   3.  38. -63.]
# Iterations: 100
# Method time: 0.006178891286253929 seconds
#
# Jacobi:
# Solution: [14. 22. 33. 26. 22.]
# Iterations: 100
# Method time: 0.0033482834696769714 seconds
